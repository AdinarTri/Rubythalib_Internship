# %% [markdown]
# [OpenCV](https://opencv.org/)

# %% [markdown]
# ### Image Cropping
#
# [Documentation](https://opencv.org/blog/cropping-an-image-using-opencv/)

# %%
import sys
print(sys.executable)
# %pip install opencv-python
# Out:
# c:\Users\LEGION\AppData\Local\Programs\Python\Python312\python.exe
# ...
#    ---------------------------------------- 0.0/44.0 MB ? eta -:--:--
#    ---------------------------------------- 0.0/44.0 MB ? eta -:--:--
#    ---------------------------------------- 0.1/44.0 MB 1.3 MB/s eta 0:00:34
#    ---------------------------------------- 0.2/44.0 MB 1.8 MB/s eta 0:00:25
#    ---------------------------------------- 0.5/44.0 MB 2.6 MB/s eta 0:00:18
#     --------------------------------------- 0.7/44.0 MB 3.1 MB/s eta 0:00:14
#     --------------------------------------- 0.7/44.0 MB 3.2 MB/s eta 0:00:14
#     --------------------------------------- 0.7/44.0 MB 2.5 MB/s eta 0:00:18
#     --------------------------------------- 1.0/44.0 MB 2.8 MB/s eta 0:00:16
#    - -------------------------------------- 1.3/44.0 MB 3.1 MB/s eta 0:00:14
#    - -------------------------------------- 1.5/44.0 MB 3.2 MB/s eta 0:00:14
# ...

# %%
import cv2
import numpy as np

# Baca gambar
image = cv2.imread("foto.png")

# Cek apakah gambar berhasil dibaca
if image is None:
    print("Gambar tidak ditemukan!")
else:
    # Koordinat cropping
    y_start = 50
    y_end = 200
    x_start = 100
    x_end = 300

    # Crop image
    cropped_image = image[y_start:y_end, x_start:x_end]

    # Simpan hasil crop
    cv2.imwrite("cropped_image.jpg", cropped_image)

    print("Image cropped and saved as 'cropped_image.jpg'")
# Out:
# Image cropped and saved as 'cropped_image.jpg'

# %%
import cv2
import matplotlib.pyplot as plt

# Baca gambar
image = cv2.imread('foto.png')

# Tentukan koordinat cropping
cropped_image = image[50:200, 100:300]

image_rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
cropped_rgb = cv2.cvtColor(cropped_image, cv2.COLOR_BGR2RGB)

    # Tampilkan gambar asli dan hasil crop
plt.figure(figsize=(10, 5))

plt.subplot(1, 2, 1)
plt.imshow(image_rgb)
plt.title("Gambar Asli")
plt.axis("off")
plt.subplot(1, 2, 2)
plt.imshow(cropped_rgb)
plt.title("Hasil Crop")
plt.axis("off")

plt.show()

# %% [markdown]
# ### Grayscale

# %%
import cv2
import matplotlib.pyplot as plt

# Baca gambar
image = cv2.imread('foto.png')


    # Tampilkan gambar asli dan hasil crop

  # Konversi ke grayscale
grayscale_image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

  # Simpan hasil grayscale
cv2.imwrite('grayscale_image.jpg', grayscale_image)

  # Display the grayscale image
display(Image('grayscale_image.jpg', width=300))

print("Image converted to grayscale and saved as 'grayscale_image.jpg'")
# Out:
# Image converted to grayscale and saved as 'grayscale_image.jpg'

# %%
import cv2

# Baca gambar
image = cv2.imread('input_image.png')

# Konversi ke grayscale
grayscale_image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

# Simpan hasil grayscale
cv2.imwrite('grayscale_image.jpg', grayscale_image)
# Out:
# True

# %% [markdown]
# ### Channel Split

# %%
from IPython.display import Image
import cv2
import numpy as np


image = cv2.imread('foto.png')

  # Pisahkan saluran warna
blue_channel, green_channel, red_channel = cv2.split(image)


# Buat channel RGB berwarna
red_image = np.zeros_like(image)
green_image = np.zeros_like(image)
blue_image = np.zeros_like(image)

# Masukkan masing-masing channel
red_image[:, :, 2] = red_channel
green_image[:, :, 1] = green_channel
blue_image[:, :, 0] = blue_channel

  # Simpan hasil channel split
cv2.imwrite('red_channel.jpg', red_image)
cv2.imwrite('green_channel.jpg', green_image)
cv2.imwrite('blue_channel.jpg', blue_image)

  # Tampilkan
display(Image('red_channel.jpg',width=300))
display(Image('green_channel.jpg',width=300))
display(Image('blue_channel.jpg',width=300))

print("Image converted to Channel Split and saved")
# Out:
# Image converted to Channel Split and saved

# %%
import cv2

# Baca gambar
image = cv2.imread('input_image.png')

# Pisahkan saluran warna
blue_channel, green_channel, red_channel = cv2.split(image)

# Simpan hasil channel split
cv2.imwrite('red_channel.jpg', red_channel)
cv2.imwrite('green_channel.jpg', green_channel)
cv2.imwrite('blue_channel.jpg', blue_channel)
# Out:
# True

# %% [markdown]
# ### Convolution

# %%
from google.colab import files
from IPython.display import Image
import cv2
import numpy as np

uploaded = files.upload()

for fn in uploaded.keys():
  print('User uploaded file "{name}" with length {length} bytes'.format(
      name=fn, length=len(uploaded[fn])))
  display(Image(fn))

  # Read the uploaded image using OpenCV
  image = cv2.imread(fn)

  # Definisikan kernel untuk blur
  kernel = np.ones((9, 9), np.float32) / 81

  # Terapkan konvolusi dengan filter (blur)
  convolved_image = cv2.filter2D(image, -1, kernel)

  # Simpan hasil konvolusi
  cv2.imwrite('convolved_image.jpg', convolved_image)
# Out:
#      <input type="file" id="files-9798f705-23b9-40e2-8506-9091374bdea1" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-9798f705-23b9-40e2-8506-9091374bdea1">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import cv2
import numpy as np

# Baca gambar
image = cv2.imread('input_image.png')

# Definisikan kernel untuk blur
kernel = np.ones((5, 5), np.float32) / 25

# Terapkan konvolusi dengan filter (blur)
convolved_image = cv2.filter2D(image, -1, kernel)

# Simpan hasil konvolusi
cv2.imwrite('convolved_image.jpg', convolved_image)
# Out:
# True

# %% [markdown]
# ### Line Detection

# %%
from google.colab import files
from IPython.display import Image
import cv2
import numpy as np

uploaded = files.upload()

for fn in uploaded.keys():
  print('User uploaded file "{name}" with length {length} bytes'.format(
      name=fn, length=len(uploaded[fn])))
  display(Image(fn))

  # Read the uploaded image using OpenCV
  image = cv2.imread(fn)

  gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

  # Deteksi tepi menggunakan Canny
  edges = cv2.Canny(gray, 50, 150, apertureSize=3)

  # Deteksi garis menggunakan Hough Transform
  lines = cv2.HoughLines(edges, 1, np.pi / 180, 200)

  # Gambar garis pada gambar asli

  if lines is not None:
    for rho, theta in lines[:, 0]:
      a = np.cos(theta)
      b = np.sin(theta)
      x0 = a * rho
      y0 = b * rho
      x1 = int(x0 + 1000 * (-b))
      y1 = int(y0 + 1000 * (a))
      x2 = int(x0 - 1000 * (-b))
      y2 = int(y0 - 1000 * (a))
      cv2.line(image, (x1, y1), (x2, y2), (0, 0, 255), 2)

  # Simpan hasil deteksi garis
  cv2.imwrite('line_detected_image.jpg', image)
# Out:
#      <input type="file" id="files-fd5aba82-8e33-445d-a751-ad196ae1e1d8" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-fd5aba82-8e33-445d-a751-ad196ae1e1d8">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import cv2
import numpy as np

# Baca gambar dan konversi ke grayscale
image = cv2.imread('input_image.png')
gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

# Deteksi tepi menggunakan Canny
edges = cv2.Canny(gray, 50, 150, apertureSize=3)

# Deteksi garis menggunakan Hough Transform
lines = cv2.HoughLines(edges, 1, np.pi / 180, 200)

# Gambar garis pada gambar asli

if lines is not None:
 for rho, theta in lines[:, 0]:
  a = np.cos(theta)
  b = np.sin(theta)
  x0 = a * rho
  y0 = b * rho
  x1 = int(x0 + 1000 * (-b))
  y1 = int(y0 + 1000 * (a))
  x2 = int(x0 - 1000 * (-b))
  y2 = int(y0 - 1000 * (a))
  cv2.line(image, (x1, y1), (x2, y2), (0, 0, 255), 2)


# Simpan hasil deteksi garis
cv2.imwrite('line_detected_image.jpg', image)
# Out:
# True

# %% [markdown]
# Edge Detection [Documentation](https://opencv.org/blog/edge-detection-using-opencv/)

# %%
import numpy as np
import cv2 as cv
from matplotlib import pyplot as plt

img = cv.imread('Image_1.png', cv.IMREAD_GRAYSCALE)
assert img is not None, "file could not be read, check with os.path.exists()"
edges = cv.Canny(img,100,200)

plt.subplot(121),plt.imshow(img,cmap = 'gray')
plt.title('Original Image'), plt.xticks([]), plt.yticks([])
plt.subplot(122),plt.imshow(edges,cmap = 'gray')
plt.title('Edge Image'), plt.xticks([]), plt.yticks([])

plt.show()

# %%
# Apply Sobel operator
sobelx = cv2.Sobel(img, cv2.CV_64F, 1, 0, ksize=3)  # Horizontal edges
sobely = cv2.Sobel(img, cv2.CV_64F, 0, 1, ksize=3)  # Vertical edges

# Compute gradient magnitude
gradient_magnitude = cv2.magnitude(sobelx, sobely)

# Convert to uint8
gradient_magnitude = cv2.convertScaleAbs(gradient_magnitude)

cv2.imwrite('sobel_edge_detection.jpg', gradient_magnitude)
# Out:
# True

# %%
# Apply Laplacian operator
laplacian = cv2.Laplacian(img, cv2.CV_64F)

# Convert to uint8
laplacian_abs = cv2.convertScaleAbs(laplacian)

cv2.imwrite('laplacian_detection.jpg', laplacian_abs)
# Out:
# True

# %%
# Apply Gaussian Blur to reduce noise
blur = cv2.GaussianBlur(img, (5, 5), 1.4)

# Apply Canny Edge Detector
edges = cv2.Canny(blur, threshold1=100, threshold2=200)

cv2.imwrite('canny_edge_detection.jpg', edges)
# Out:
# True
